# %%
#import the necessary modules and packages

import pandas as pd
import numpy as np
from sklearn.neighbors import NearestNeighbors
import matplotlib.pyplot as plt
from ast import literal_eval
from sklearn.feature_extraction.text import CountVectorizer
from IPython.display import display

# %%
#read the datasets and merge them on the common column id and perform data type conversions

md= pd.read_csv('movies_metadata.csv',low_memory=False)
cred= pd.read_csv('credits.csv')
kd= pd.read_csv('keywords.csv')
md= md[['id','title','overview','genres','vote_average','vote_count','adult']]
md['id']=pd.to_numeric(md['id'],errors='coerce')

md= pd.merge(md,cred)
md= pd.merge(md,kd)
md=md.drop_duplicates(subset=['title'])
md.head()
# Out:
#         id                        title  \
# 0    862.0                    Toy Story
# 1   8844.0                      Jumanji
# 2  15602.0             Grumpier Old Men
# 3  31357.0            Waiting to Exhale
# 4  11862.0  Father of the Bride Part II
#
#                                             overview  \
# 0  Led by Woody, Andy's toys live happily in his ...
# 1  When siblings Judy and Peter discover an encha...
# 2  A family wedding reignites the ancient feud be...
# 3  Cheated on, mistreated and stepped on, the wom...
# 4  Just when George Banks has recovered from his ...
#
#                                               genres  vote_average  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...           7.7
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...           6.9
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...           6.5
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...           6.1
# 4                     [{'id': 35, 'name': 'Comedy'}]           5.7
#
#    vote_count  adult                                               cast  \
# 0      5415.0  False  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1      2413.0  False  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2        92.0  False  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3        34.0  False  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4       173.0  False  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew  \
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...
#
#                                             keywords
# 0  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2  [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 4  [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...

# %%
#the lists in our dataset are stringified convert them into pyhton lists
features =['genres','cast','crew','keywords']
for feature in features:
    md[feature] = md[feature].apply(literal_eval)

# %%
#handle empty values in columns
md['overview']=md['overview'].fillna('')
md= md[md['genres'].map(len)>=1]
md= md[md['cast'].map(len)>=1]
md= md[md['crew'].map(len)>=1]
md= md[md['keywords'].map(len)>=1]

# %%
#Extract top 3 values from genre, cast and keywords
def get_feature(feature):
    final,lis=[],[]
    for i in md[feature]:
        if len(i)>=3:
            for j in i[0:3]:
                lis.append(j['name'])
        else:
            lis.append(i[0]['name'])
        final.append(lis)
        lis=[]
    return final


for feature in features:
    if feature!='crew':
        md[feature]=get_feature(feature)

# %%
#extract the directors from crew column
def get_director():
    lis,direc=[],[]
    for i in md.crew:
        for j in i:
            if j['job']=='Director':
                lis.append(j['name'])
        direc.append(lis)
        lis=[]

    return direc

# %%
md['Director']= get_director()
md= md[md['Director'].map(len)>=1]
md.drop('crew',axis=1,inplace=True)

# %%
md['Director'] = [x[0] for x in md['Director']]

# %%
md['id']= md['id'].astype(int) #Some more type conversions to maintain uniformity
md.isnull().sum() #we see missing values in vote_average,counts and titles, drop them
# Out:
# id              0
# title           1
# overview        0
# genres          0
# vote_average    1
# vote_count      1
# adult           0
# cast            0
# keywords        0
# Director        0
# dtype: int64

# %%
md.dropna(inplace=True) # drop the na rows

# %%
v = md['vote_count']
R = md['vote_average']
C= md['vote_average'].mean()
m= md['vote_count'].quantile(0.97)
md['Rating']=np.round((v/(v+m) * R) + (m/(m+v) * C),1)

# %%
#Our final data is ready for model development
md.head()
# Out:
#       id                        title  \
# 0    862                    Toy Story
# 1   8844                      Jumanji
# 2  15602             Grumpier Old Men
# 3  31357            Waiting to Exhale
# 4  11862  Father of the Bride Part II
#
#                                             overview  \
# 0  Led by Woody, Andy's toys live happily in his ...
# 1  When siblings Judy and Peter discover an encha...
# 2  A family wedding reignites the ancient feud be...
# 3  Cheated on, mistreated and stepped on, the wom...
# 4  Just when George Banks has recovered from his ...
#
#                          genres  vote_average  vote_count  adult  \
# 0   [Animation, Comedy, Family]           7.7      5415.0  False
# 1  [Adventure, Fantasy, Family]           6.9      2413.0  False
# 2                     [Romance]           6.5        92.0  False
# 3      [Comedy, Drama, Romance]           6.1        34.0  False
# 4                      [Comedy]           5.7       173.0  False
#
#                                                 cast  \
# 0                [Tom Hanks, Tim Allen, Don Rickles]
# 1     [Robin Williams, Jonathan Hyde, Kirsten Dunst]
# 2         [Walter Matthau, Jack Lemmon, Ann-Margret]
# 3  [Whitney Houston, Angela Bassett, Loretta Devine]
# 4         [Steve Martin, Diane Keaton, Martin Short]
#
#                                             keywords         Director  Rating
# 0                               [jealousy, toy, boy]    John Lasseter     7.4
# 1  [board game, disappearance, based on children'...     Joe Johnston     6.5
# 2       [fishing, best friend, duringcreditsstinger]    Howard Deutch     5.9
# 3  [based on novel, interracial relationship, sin...  Forest Whitaker     5.9
# 4                 [baby, midlife crisis, confidence]    Charles Shyer     5.8

# %%
md.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27734 entries, 0 to 46624
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            27734 non-null  int32
#  1   title         27734 non-null  object
#  2   overview      27734 non-null  object
#  3   genres        27734 non-null  object
#  4   vote_average  27734 non-null  float64
#  5   vote_count    27734 non-null  float64
#  6   adult         27734 non-null  object
#  7   cast          27734 non-null  object
#  8   keywords      27734 non-null  object
#  9   Director      27734 non-null  object
#  10  Rating        27734 non-null  float64
# dtypes: float64(3), int32(1), object(7)
# memory usage: 2.4+ MB

# %%
#Recommendation based on vote_score
#We need to create a weighted vote column as vote_count and vote_average vary independently

def gen_top(x,n):
    cond_1=x['vote_average']>C
    cond_2=x['vote_count']>m
    x=x[cond_1&cond_2]
    return x[['title','genres','overview','cast','keywords','Director','Rating']].head(n).sort_values(by="Rating",ascending=False).set_index([np.arange(1,n+1)])



gen_top(md,10)
# Out:
#                   title                                genres  \
# 1                 Se7en            [Crime, Mystery, Thriller]
# 2    The Usual Suspects              [Drama, Crime, Thriller]
# 3             Toy Story           [Animation, Comedy, Family]
# 4            Braveheart              [Action, Drama, History]
# 5                  Heat                [Action, Crime, Drama]
# 6                Casino                               [Drama]
# 7        Twelve Monkeys  [Science Fiction, Thriller, Mystery]
# 8               Jumanji          [Adventure, Fantasy, Family]
# 9   From Dusk Till Dawn            [Horror, Action, Thriller]
# 10           Pocahontas         [Adventure, Animation, Drama]
#
#                                              overview  \
# 1   Two homicide detectives are on a desperate hun...
# 2   Held in an L.A. interrogation room, Verbal Kin...
# 3   Led by Woody, Andy's toys live happily in his ...
# 4   Enraged at the slaughter of Murron, his new br...
# 5   Obsessive master thief, Neil McCauley leads a ...
# 6   The life of the gambling paradise – Las Vegas ...
# 7   In the year 2035, convict James Cole reluctant...
# 8   When siblings Judy and Peter discover an encha...
# 9   Seth Gecko and his younger brother Richard are...
# 10  History comes gloriously to life in Disney's e...
#
#                                                  cast  \
# 1        [Brad Pitt, Morgan Freeman, Gwyneth Paltrow]
# 2   [Stephen Baldwin, Gabriel Byrne, Chazz Palmint...
# 3                 [Tom Hanks, Tim Allen, Don Rickles]
# 4   [Mel Gibson, Catherine McCormack, Sophie Marceau]
# 5             [Al Pacino, Robert De Niro, Val Kilmer]
# 6           [Robert De Niro, Sharon Stone, Joe Pesci]
# 7          [Bruce Willis, Madeleine Stowe, Brad Pitt]
# 8      [Robin Williams, Jonathan Hyde, Kirsten Dunst]
# 9   [George Clooney, Quentin Tarantino, Harvey Kei...
# 10     [Irene Bedard, Mel Gibson, David Ogden Stiers]
#
#                                              keywords          Director  \
# 1     [self-fulfilling prophecy, detective, s.w.a.t.]     David Fincher
# 2                             [law, relatives, theft]      Bryan Singer
# 3                                [jealousy, toy, boy]     John Lasseter
# 4          [individual, scotland, in love with enemy]        Mel Gibson
# 5                          [robbery, detective, bank]      Michael Mann
# 6                          [poker, drug abuse, 1970s]   Martin Scorsese
# 7    [schizophrenia, philadelphia, cassandra syndrom]     Terry Gilliam
# 8   [board game, disappearance, based on children'...      Joe Johnston
# 9   [dancing, brother brother relationship, sexual...  Robert Rodriguez
# 10           [culture clash, settler, forbidden love]      Mike Gabriel
#
#     Rating
# 1      7.7
# 2      7.5
# 3      7.4
# 4      7.2
# 5      7.0
# 6      6.9
# 7      6.9
# 8      6.5
# 9      6.4
# 10     6.3

# %%
#Recommendation based on genre,keywords and directors
#first we have to clean the data of spaces
adv_md= md.copy() #make a copy for this model
def clean(x):
    if isinstance(x,list):
        fin_lis= [str.lower(i.replace(' ','')) for i in x]
        return ''.join(fin_lis)
    else:
        return str.lower(x.replace(' ',''))      
for feature in ['genres','cast','keywords','Director']:
    adv_md[feature]= adv_md[feature].apply(clean)
adv_md.head()
# Out:
#       id                        title  \
# 0    862                    Toy Story
# 1   8844                      Jumanji
# 2  15602             Grumpier Old Men
# 3  31357            Waiting to Exhale
# 4  11862  Father of the Bride Part II
#
#                                             overview                  genres  \
# 0  Led by Woody, Andy's toys live happily in his ...   animationcomedyfamily
# 1  When siblings Judy and Peter discover an encha...  adventurefantasyfamily
# 2  A family wedding reignites the ancient feud be...                 romance
# 3  Cheated on, mistreated and stepped on, the wom...      comedydramaromance
# 4  Just when George Banks has recovered from his ...                  comedy
#
#    vote_average  vote_count  adult                                      cast  \
# 0           7.7      5415.0  False                tomhankstimallendonrickles
# 1           6.9      2413.0  False     robinwilliamsjonathanhydekirstendunst
# 2           6.5        92.0  False        waltermatthaujacklemmonann-margret
# 3           6.1        34.0  False  whitneyhoustonangelabassettlorettadevine
# 4           5.7       173.0  False         stevemartindianekeatonmartinshort
#
#                                           keywords        Director  Rating
# 0                                   jealousytoyboy    johnlasseter     7.4
# 1      boardgamedisappearancebasedonchildren'sbook     joejohnston     6.5
# 2            fishingbestfriendduringcreditsstinger    howarddeutch     5.9
# 3  basedonnovelinterracialrelationshipsinglemother  forestwhitaker     5.9
# 4                      babymidlifecrisisconfidence    charlesshyer     5.8

# %%
#we create the feature column having all these features combined
adv_md['feat']= adv_md['genres']+' '+adv_md['cast']+' '+adv_md['keywords']+' '+adv_md['Director']
adv_md['feat'].head()
# Out:
# 0    animationcomedyfamily tomhankstimallendonrickl...
# 1    adventurefantasyfamily robinwilliamsjonathanhy...
# 2    romance waltermatthaujacklemmonann-margret fis...
# 3    comedydramaromance whitneyhoustonangelabassett...
# 4    comedy stevemartindianekeatonmartinshort babym...
# Name: feat, dtype: object

# %%
# Develop the model

vectorizer= CountVectorizer()
X= vectorizer.fit_transform(adv_md['feat'])
knn= NearestNeighbors(algorithm='brute')
knn.fit(X)
# Out:
# NearestNeighbors(algorithm='brute')

# %%
adv_md=adv_md.set_index([np.arange(0,len(adv_md))])

# %%
#Make recommendation


def recommend(title,n=5):
    movie_idx= adv_md[adv_md['title']==title].index[0]
    distances, indices = knn.kneighbors(X[movie_idx], n_neighbors=n+1)
    similar_movies= indices.flatten()[1:]
    return similar_movies
    

def genre_rec(genre,n):
    genre=genre.lower()
    movie_idx= adv_md[adv_md['genres'].str.contains(genre)].index[0]
    distances, indices = knn.kneighbors(X[movie_idx], n_neighbors=n+1)
    similar_movies= indices.flatten()[1:]
    return similar_movies
    
type = int(input("Enter 1 for genre, 2 for movie name: "))
n= int(input("Enter number of movies to be recommended"))
if type==1:
    genre= input("Enter genre")
    display(md.iloc[genre_rec(genre,n)].drop(['id','vote_average','vote_count'],axis=1).sort_values(by='Rating',ascending=False))
else:
    name= input("Enter movie name(Case-sensitive, punctuative!!): ")
    display(md.iloc[recommend(name,n)].drop(['id','vote_average','vote_count'],axis=1).sort_values(by='Rating',ascending=False))
# Out:
#                             title  \
# 4900                          Ali
# 5759                        Thief
# 1529                     Cop Land
# 11002               The Protector
# 13615  The Baader Meinhof Complex
# 9125                       Pusher
# 12077              Death Sentence
# 6537                     The Keep
# 16189              The Small Town
# 7576                   The Yakuza
# 39784                    Skinning
# 38249              Rakht Charitra
# 19789            Rx (Simple Lies)
# 23913                      Gunday
# 4744                    Brannigan
# 7106                 No Good Deed
# 10398        Revenge of the Ninja
# 10809              Helter Skelter
# 15226                Chained Heat
# 39369                  I Am Wrath
#
#                                                 overview  \
# 4900   In 1964, a brash new pro boxer, fresh from his...
# 5759   Frank is an expert professional safecracker, s...
# 1529   Freddy Heflin is the sheriff of a place everyo...
# 11002  In Bangkok, the young Kham was raised by his f...
# 13615  Der Baader Meinhof Komplex depicts the politic...
# 9125   A drug pusher grows increasingly desperate aft...
# 12077  Nick Hume is a mild-mannered executive with a ...
# 6537   Nazis take over an ancient fortress that conta...
# 16189  The story of a family living in a small godfor...
# 7576   Harry Kilmer returns to Japan after several ye...
# 39784  Novica is a mathematics champion in a Belgrade...
# 38249  A killer bandit decides to become a politician...
# 19789  What is meant to be a weekend party across the...
# 23913  Based in Calcutta during its most unsettled ti...
# 4744   Jim Brannigan is sent to London to bring back ...
# 7106   While doing a friend a favor and searching for...
# 10398  After his family is killed in Japan by ninjas,...
# 10809  A new take on the Manson Family murders, with ...
# 15226  Linda Blair plays Carol, a young woman who mus...
# 39369  A man is out for justice after a group of corr...
#
#                        genres  adult  \
# 4900                  [Drama]  False
# 5759   [Action, Crime, Drama]  False
# 1529   [Action, Crime, Drama]  False
# 11002  [Action, Crime, Drama]  False
# 13615  [Action, Crime, Drama]  False
# 9125   [Action, Crime, Drama]  False
# 12077  [Action, Crime, Drama]  False
# 6537                 [Horror]  False
# 16189  [Action, Crime, Drama]  False
# 7576   [Action, Crime, Drama]  False
# 39784  [Action, Crime, Drama]  False
# 38249  [Action, Crime, Drama]  False
# 19789  [Action, Crime, Drama]  False
# 23913  [Action, Crime, Drama]  False
# 4744   [Action, Crime, Drama]  False
# 7106   [Action, Crime, Drama]  False
